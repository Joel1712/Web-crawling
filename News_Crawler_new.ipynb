# %% [markdown]
# # Web scraping from Indian Express website

# %%
import requests
from bs4 import BeautifulSoup
from newspaper import Article
import pandas as pd
import numpy as np
import re

# %%
def scraper(url):
    c=0;article_links=[]
    r = requests.get(url);soup = BeautifulSoup(r.content, 'html5lib')
    
    while(soup.find('div',{'class':'pagination'}).find('a',{'class':'page-numbers'}) and c<2):
    #for page navigation ,however we have limited manumber of pages visited to 2
        
        articles=soup.find('div',{'class':'nation'}).findAll('div',{'class':'articles'})
        for news in articles:
            data={}
            article_links.append(news.find('a')['href'])

        url=soup.find('div',{'class':'pagination'}).find('a',{'class':'next page-numbers'})['href']
        r = requests.get(url);soup = BeautifulSoup(r.content, 'html5lib')
        c+=1
    return article_links

list=['world','lifestyle','business','entertainment']

df=[]
for l in list:
    url = "https://indianexpress.com/section/"+l+"/"
    links=scraper(url)
    for link in links:dat={'links':link,'Category':l};df.append(dat)

for l in df:
    article = Article(l['links'], language="en")
    article.download();article.parse();article.nlp()
    l['Title']=article.title
    l['Text']=article.text
    l['keywords']=article.keywords
    l['date']=article.publish_date

# %%
df=pd.DataFrame(df)
df.to_csv('News.csv')#saving scraped data to News.csv
df.head()
# Out:
#   Category                                               Text  \
# 0    world  Dr Lorna Green was a medical director at NewYo...
# 1    world  The Spain government has announced that if the...
# 2    world  In this May 21, 1987, then North Korean Presid...
# 3    world  Japan is also in the same scramble for protect...
# 4    world  US coronavirus deaths surpassed 56,000 on Mond...
#
#                                                Title  \
# 0  New York doctor, who resumed work after Covid-...
# 1  Lifting lockdowns, European nations go their o...
# 2  A look at past disappearances of North Korean ...
# 3  On Japan’s stretched frontline, doctors and nu...
# 4  US coronavirus deaths projected at over 74,000...
#
#                        date  \
# 0 2020-04-28 16:10:23+05:30
# 1 2020-04-28 15:05:07+05:30
# 2 2020-04-28 15:00:27+05:30
# 3 2020-04-28 15:00:25+05:30
# 4 2020-04-28 14:52:52+05:30
#
#                                             keywords  \
# 0  [doctor, york, breen, hospital, dr, takes, cov...
# 1  [lifting, open, way, children, prime, restrict...
# 2  [jong, sung, leaders, koreas, officials, disap...
# 3  [icu, stretched, hospital, japans, frontline, ...
# 4  [deaths, death, projected, 74000, according, u...
#
#                                                links
# 0  https://indianexpress.com/article/world/lorna-...
# 1  https://indianexpress.com/article/world/liftin...
# 2  https://indianexpress.com/article/world/north-...
# 3  https://indianexpress.com/article/world/on-jap...
# 4  https://indianexpress.com/article/world/us-cor...

# %% [markdown]
# # Converting scraped data into UCI dataset format for analysis

# %%
import datetime 
import calendar
from textblob import TextBlob
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords 

def findDay(dt): 
    d_truncated = datetime.date(dt.year, dt.month, dt.day)
    return calendar.day_name[d_truncated.weekday()]

# %%
def cleaner(text):#to format the input text
    text=' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", text).split())
    text=text.lower()
    return text

def rate_words(text):#to find rate_positive_words ,polarity ,min/max_negative_polarity and ...
    text=cleaner(text)
    w_p=[];w_n=[];l1=[];l2=[]
    text=word_tokenize(text)
    for word in text:
        t=TextBlob(word).sentiment.polarity
        if(t>0):w_p.append(t)
        elif(t<0):w_n.append(t)
    le1=len(w_p);le2=len(w_n);let=len(text)
    if(w_p):l1=[le1/let,le1/(le2+le1),sum(w_p)/le1,min(w_p),max(w_p)]
    if(w_n):l2=[le2/let,le2/(le2+le1),sum(w_n)/le2,min(w_n),max(w_n)]
    return l1,l2

def token_counter(text):#to find n_tokens_content,non stop words and ...
    text=cleaner(text)
    text=word_tokenize(text)
    stop_words = set(stopwords.words('english')) 
    filtered_text = [w for w in text if not w in stop_words]
    n_non_stop_words=len(filtered_text)/len(text)
    n_unique_tokens=len(set(text))/len(text)
    n_non_stop_unique_tokens=len(set(filtered_text))/len(text)
    average = sum(len(word) for word in text) / len(text)
    return len(text),n_unique_tokens,n_non_stop_words,n_non_stop_unique_tokens,average
    
def sentiment(text): # to find subjectivity and polaity 
    text=cleaner(text)
    analysis = TextBlob(text) 
    return (analysis.sentiment.polarity,analysis.sentiment.subjectivity)

# %% [markdown]
# ### Using utility functions to convert data to UCI dataset format

# %%
dat_fr=[]
for ind in df.index: 
    dat={}
    tr,_,_,_,_=token_counter(df['Title'][ind])
    dat[' n_tokens_title']=tr
    
    a,b,c,d,e=token_counter(df['Text'][ind])
    dat[' n_tokens_content']=a;dat[' n_unique_tokens']=b
    dat[' n_non_stop_words']=c;dat[' n_non_stop_unique_tokens']=d;dat[' average_token_length']=e
    
    dat[' num_keywords']=len(df['keywords'][ind])
    
    cat=df['Category'][ind]
    if(cat=='lifestyle'):dat[' data_channel_is_lifestyle']=1
    if(cat=='business'):dat[' data_channel_is_bus']=1
    if(cat=='world'):dat[' data_channel_is_world']=1
    if(cat=='entertainment'):dat[' data_channel_is_entertainment']=1
        
    day=findDay(df['date'][ind])
    dat[' weekday_is_monday']=1 if(day[0]=='Monday') else 0
    dat[' weekday_is_tuesday']=1 if(day[0]=='Tuesday') else 0
    dat[' weekday_is_wednesday']=1 if(day[0]=='Wednesday') else 0
    dat[' weekday_is_thursday']=1 if(day[0]=='Thursday') else 0
    dat[' weekday_is_friday']=1 if(day[0]=='Friday') else 0
    dat[' weekday_is_saturday']=1 if(day[0]=='Saturday') else 0
    dat[' weekday_is_sunday']=1 if(day[0]=='Sunday') else 0
    dat[' is_weekend']=1 if(day[0]=='Saturday' or day[0]=='Sunday') else 0
   
    x,y=sentiment(df['Text'][ind])
    dat[' global_subjectivity']=y;dat[' global_sentiment_polarity']=x
    q,w=sentiment(df['Title'][ind])
    dat[' title_subjectivity']=w;dat[' title_sentiment_polarity']=q
    
    l1,l2=rate_words(df['Text'][ind])
    
    if(l1):
        dat[' global_rate_positive_words']=l1[0];dat[' rate_positive_words']=l1[1]
        dat[' avg_positive_polarity']=l1[2];dat[' min_positive_polarity']=l1[3]
        dat[' max_positive_polarity']=l1[4]
    
    if(l2):
        dat[' global_rate_negative_words']=l2[0];dat[' rate_negative_words']=l2[1]
        dat[' avg_negative_polarity']=l2[2];dat[' min_negative_polarity']=l2[3]
        dat[' max_negative_polarity']=l2[4]
    
    dat_fr.append(dat)

# %%
dat_fr=pd.DataFrame(dat_fr)
dat_fr.head()
# Out:
#     average_token_length   avg_negative_polarity   avg_positive_polarity  \
# 0               4.453368               -0.173333                0.305966
# 1               4.989575               -0.201560                0.343895
# 2               4.768786               -0.267070                0.317523
# 3               4.944444               -0.270859                0.339461
# 4               4.856140               -0.251852                0.323636
#
#     data_channel_is_bus   data_channel_is_entertainment  \
# 0                   NaN                             NaN
# 1                   NaN                             NaN
# 2                   NaN                             NaN
# 3                   NaN                             NaN
# 4                   NaN                             NaN
#
#     data_channel_is_lifestyle   data_channel_is_world  \
# 0                         NaN                     1.0
# 1                         NaN                     1.0
# 2                         NaN                     1.0
# 3                         NaN                     1.0
# 4                         NaN                     1.0
#
#     global_rate_negative_words   global_rate_positive_words  \
# 0                     0.012953                     0.041451
# 1                     0.020048                     0.028067
# 2                     0.029865                     0.022158
# 3                     0.017504                     0.028158
# 4                     0.010526                     0.038596
#
#     global_sentiment_polarity  ...   rate_positive_words  \
# 0                    0.125900  ...              0.761905
# 1                    0.061220  ...              0.583333
# 2                   -0.032316  ...              0.425926
# 3                    0.047909  ...              0.616667
# 4                    0.127475  ...              0.785714
#
#     title_sentiment_polarity   title_subjectivity   weekday_is_friday  \
# 0                   0.368182             0.727273                   0
# 1                   0.300000             0.500000                   0
# 2                  -0.250000             0.250000                   0
# 3                  -0.050000             0.000000                   0
# 4                   0.000000             0.000000                   0
#
#     weekday_is_monday   weekday_is_saturday   weekday_is_sunday  \
# 0                   0                     0                   0
# 1                   0                     0                   0
# 2                   0                     0                   0
# 3                   0                     0                   0
# 4                   0                     0                   0
#
#     weekday_is_thursday   weekday_is_tuesday   weekday_is_wednesday
# 0                     0                    1                      0
# 1                     0                    1                      0
# 2                     0                    1                      0
# 3                     0                    1                      0
# 4                     0                    1                      0
#
# [5 rows x 33 columns]

# %% [markdown]
# # Predictive model based on UCI dataset

# %%
database=pd.read_csv('UCI dataset\\OnlineNewsPopularity\\OnlineNewsPopularity.csv')
target=database[' shares']
l1=['url',' data_channel_is_tech',' data_channel_is_socmed',' num_imgs',' num_videos',' self_reference_min_shares',
    ' self_reference_max_shares',' self_reference_avg_sharess',' LDA_00',' LDA_01',' LDA_02',' LDA_03',' LDA_04',
    ' num_self_hrefs',' num_hrefs',' shares',' kw_min_max', ' kw_max_max', ' kw_avg_max', ' kw_min_avg',
    ' kw_max_avg', ' kw_avg_avg',' kw_min_min', ' kw_max_min', ' kw_avg_min',' abs_title_subjectivity', 
    ' abs_title_sentiment_polarity',' timedelta']
database=database.drop(columns=l1)#droping features which may not be significant in our case

database.to_csv('UCI_dataset.csv')
database.head()
# Out:
#     n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0             12.0              219.0          0.663594                1.0
# 1              9.0              255.0          0.604743                1.0
# 2              9.0              211.0          0.575130                1.0
# 3              9.0              531.0          0.503788                1.0
# 4             13.0             1072.0          0.415646                1.0
#
#     n_non_stop_unique_tokens   average_token_length   num_keywords  \
# 0                   0.815385               4.680365            5.0
# 1                   0.791946               4.913725            4.0
# 2                   0.663866               4.393365            6.0
# 3                   0.665635               4.404896            7.0
# 4                   0.540890               4.682836            7.0
#
#     data_channel_is_lifestyle   data_channel_is_entertainment  \
# 0                         0.0                             1.0
# 1                         0.0                             0.0
# 2                         0.0                             0.0
# 3                         0.0                             1.0
# 4                         0.0                             0.0
#
#     data_channel_is_bus  ...   rate_positive_words   rate_negative_words  \
# 0                   0.0  ...              0.769231              0.230769
# 1                   1.0  ...              0.733333              0.266667
# 2                   1.0  ...              0.857143              0.142857
# 3                   0.0  ...              0.666667              0.333333
# 4                   0.0  ...              0.860215              0.139785
#
#     avg_positive_polarity   min_positive_polarity   max_positive_polarity  \
# 0                0.378636                0.100000                     0.7
# 1                0.286915                0.033333                     0.7
# 2                0.495833                0.100000                     1.0
# 3                0.385965                0.136364                     0.8
# 4                0.411127                0.033333                     1.0
#
#     avg_negative_polarity   min_negative_polarity   max_negative_polarity  \
# 0               -0.350000                  -0.600               -0.200000
# 1               -0.118750                  -0.125               -0.100000
# 2               -0.466667                  -0.800               -0.133333
# 3               -0.369697                  -0.600               -0.166667
# 4               -0.220192                  -0.500               -0.050000
#
#     title_subjectivity   title_sentiment_polarity
# 0             0.500000                  -0.187500
# 1             0.000000                   0.000000
# 2             0.000000                   0.000000
# 3             0.000000                   0.000000
# 4             0.454545                   0.136364
#
# [5 rows x 33 columns]

# %%
from sklearn.model_selection import train_test_split
#splitting of dataset for training and validation
x_train, x_test, y_train, y_test = train_test_split(database,target, test_size=0.15, random_state=0)

from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor(random_state=0,n_estimators=200)
regr.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=200,
#                       n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                       warm_start=False)

# %%
pred=regr.predict(x_test)
y_pred=regr.predict(x_train)
data={'Pred:':y_pred,'Actual:':y_train}
d1=pd.DataFrame(data)
d1.head()
# Out:
#       Pred:  Actual:
# 0  3094.450     2800
# 1  2373.420     1900
# 2  4334.785     2800
# 3  6639.385     7900
# 4  2217.815     1200

# %% [markdown]
# # Using model on scraped data

# %%
df=pd.read_csv("News.csv")
dat_fr=dat_fr.fillna(0)
prediction=regr.predict(dat_fr)
data={'Title':df['Title'],'Shares ':prediction}
d2=pd.DataFrame(data)
d2.head(100)
# Out:
#                                                 Title    Shares
# 0   New York doctor, who resumed work after Covid-...  28518.450
# 1   Lifting lockdowns, European nations go their o...  23942.635
# 2   A look at past disappearances of North Korean ...  24962.290
# 3   On Japan’s stretched frontline, doctors and nu...  22466.270
# 4   US coronavirus deaths projected at over 74,000...  21554.260
# 5   Conflict, disasters sparked 50.8 mn internal d...  19129.955
# 6   COVID-19: over 2 million people download conta...  19880.930
# 7   Health officials ready new guidelines as restr...  23286.390
# 8   Ohio’s mail-in primary tests voting during vir...  23683.815
# 9   Covid-19: UK sets up new insurance scheme for ...  25874.225
# 10  UN: $90 billion could protect 700 million poor...  27299.810
# 11  Germany Coronavirus Tracker: Region-wise cases...  28310.365
# 12  UK says some children have died from syndrome ...  22690.240
# 13  COVID-19: Signs of progress in US as deaths de...  22345.775
# 14  Japan to amend Q1 GDP calculation method to be...  21213.560
# 15  Indian national is first case in US border pro...  22556.760
# 16  China’s netizen population hit record 904 mill...  17890.905
# 17  Coronavirus Lingers in Air of Crowded Spaces, ...  22542.685
# 18  Donald Trump says virus testing ‘not a problem...  22024.060
# 19  Virus Likely to Keep Coming Back Each Year, Sa...  24078.840
# 20  Coronavirus global updates, April 28: UK on al...  23011.925
# 21  Watch: Pentagon releases ‘UFO’ footage taken b...  19756.690
# 22  World cannot afford a lost generation of youth...  20941.965
# 23  Trump faults China for coronavirus’ spread, sa...  24348.110
# 24  Coronavirus spreads fear through Latin America...  24092.300
# 25  Germany: Fines up to Euro 10,000 for not weari...  19575.955
# 26  Explained: Top theories on what’s going on wit...  22218.045
# 27  Nicolas Maduro taps US fugitive to revamp Vene...  20764.430
# 28  New Zealand reports zero domestic cases of cor...  21159.995
# 29  Afghanistan: Civilian casualties down, but hun...  22464.620
# ..                                                ...        ...
# 70  ‘We are not a trend, we are here to stay”: Nao...  19272.280
# 71  Smelly hands? Here’s how you can get rid of th...  19483.365
# 72  Shruti Haasan made the ‘easiest oven omelette’...  24025.486
# 73  Missing your favourite mac and cheese? Make it...  19739.480
# 74  Are you constipated in lockdown? Here’s why it...  19356.660
# 75  Tamannaah Bhatia and Anne Hathaway take up the...  23069.891
# 76  Get perfectly blow-dried hair with these easy ...  24872.685
# 77             Artist Zarina Hashmi passes away at 83  23090.086
# 78  Neena Gupta baked this basic cake’; check out ...  25179.296
# 79  How in the absence of helps, youngsters are ta...  19011.960
# 80  Axis Bank reports surprise $183 milllion loss ...  23397.405
# 81  BSE brings negative price feature for commodit...  24267.475
# 82  Discoms owe Rs 92,693 crore to power producers...  18663.580
# 83  Axis Bank to pick about 30% stake in Max Life ...  23415.045
# 84  Digital-ad downturn may complicate life for Go...  23588.610
# 85  Reliance Industries to consider first rights i...  20554.430
# 86  Gold falls 1% as nations plan to ease coronavi...  22726.750
# 87  Nokia bags Rs 7,500-crore deal from Bharti Airtel  22758.595
# 88  Rich Asian Families Tighten Belts, While Other...  22815.260
# 89  Oil prices dive as world runs low on storage c...  25091.160
# 90  Rupee slips 15 paise to 76.40 against US dolla...  24578.095
# 91  Sensex climbs 371 points, Nifty settles at 9,3...  23632.395
# 92    Asian shares fall on fresh rout in crude prices  26344.990
# 93  Boeing says it will need to borrow more money ...  22231.465
# 94  RBI opens Rs 50,000 cr liquidity window for mu...  22432.560
# 95  Sliding crude prices, struggling global energy...  24656.100
# 96  Going beyond 3.5% fiscal deficit target ‘unavo...  22432.560
# 97  Ind-Ra: FY21 growth to hit 29-yr low of 1.9%, ...  24178.160
# 98  Asset quality could come under stress, says In...  22432.560
# 99  FPIs continue to be sellers as markets rise on...  22732.750
#
# [100 rows x 2 columns]

# %%
average=sum(target)/len(target)
print("Average shares from UCI dataset",average)
print("Average shares from scraped data",sum(prediction)/len(prediction))
# Out:
# Average shares from UCI dataset 3395.3801836343455
# Average shares from scraped data 22937.23990625

# %% [markdown]
# ### It is clearly seen the virality(avg) of the scraped data is much higher than UCI dataset indicating that our scraped data is biased (due to limitations of resources) ,data has been scraped from top pages from website resulting in higher share
